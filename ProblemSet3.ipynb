# %% [markdown]
# # Question 3: Housing

# %%
#Step 1. Import the necessary libraries


import pandas as pd
import numpy as np

from numpy.random import randn

# %%
#Step 2. Create 3 differents Series, each of length 100, as follows:
#• The first a random number from 1 to 4
#• The second a random number from 1 to 3
#• The third a random number from 10,000 to 30,000

seriesOne = np.random.randint(1,5,100)
seriesOne
# Out:
# array([1, 4, 4, 2, 3, 1, 1, 4, 4, 3, 3, 4, 4, 2, 2, 4, 3, 4, 2, 1, 3, 4,
#        2, 3, 3, 1, 2, 4, 4, 3, 4, 3, 2, 1, 1, 4, 3, 4, 3, 4, 1, 4, 4, 3,
#        3, 2, 3, 1, 2, 1, 1, 4, 4, 1, 4, 4, 2, 2, 4, 1, 2, 2, 1, 1, 1, 3,
#        3, 4, 1, 1, 4, 3, 4, 3, 3, 1, 4, 4, 3, 2, 1, 3, 4, 4, 3, 1, 1, 1,
#        2, 4, 2, 4, 3, 1, 3, 1, 1, 4, 1, 1])

# %%
seriesTwo = np.random.randint(1,4,100)
seriesTwo
# Out:
# array([1, 2, 1, 1, 2, 3, 2, 3, 3, 1, 2, 1, 2, 2, 3, 2, 2, 1, 1, 2, 1, 2,
#        2, 1, 2, 2, 3, 3, 1, 3, 2, 3, 1, 2, 1, 1, 2, 2, 2, 1, 3, 3, 2, 2,
#        3, 1, 3, 1, 1, 2, 3, 1, 2, 1, 2, 1, 3, 1, 3, 3, 3, 2, 3, 3, 1, 1,
#        1, 3, 2, 2, 1, 3, 2, 2, 1, 1, 1, 2, 1, 2, 3, 2, 1, 3, 2, 1, 1, 2,
#        2, 3, 3, 2, 1, 3, 1, 2, 2, 3, 1, 3])

# %%
seriesThree = np.random.randint(10000, 30001, 100)
seriesThree
# Out:
# array([24247, 24274, 16109, 12763, 18699, 16778, 20327, 12499, 12277,
#        14524, 21931, 25544, 11797, 12883, 22918, 21696, 21933, 28138,
#        12680, 19692, 12109, 15307, 19596, 28840, 22618, 17000, 27690,
#        12152, 16009, 29827, 17792, 11363, 11570, 18722, 29068, 15780,
#        10089, 19006, 13206, 25911, 23003, 13938, 28476, 19715, 19268,
#        25309, 26030, 13587, 27081, 12364, 16995, 14821, 16177, 12734,
#        13251, 22646, 22282, 20507, 24977, 19865, 24490, 27806, 15181,
#        12876, 21700, 20230, 15756, 25083, 28252, 15995, 28294, 28028,
#        14512, 23318, 10828, 10482, 24843, 21255, 10579, 22870, 14301,
#        27106, 23264, 27472, 11078, 10651, 28039, 19264, 14986, 28217,
#        18372, 14678, 25099, 27674, 23946, 15598, 14240, 16336, 14623,
#        13500])

# %%
#Step 3. Create a DataFrame by joinning the Series by column


dfseriesOne = pd.Series(seriesOne)
dfseriesTwo = pd.Series(seriesTwo)
dfseriesThree = pd.Series(seriesThree)


dataFrame = pd.DataFrame({'seriesOne':dfseriesOne,'seriesTwo':dfseriesTwo,'seriesThree':dfseriesThree})
dataFrame
# Out:
#     seriesOne  seriesTwo  seriesThree
# 0           1          1        24247
# 1           4          2        24274
# 2           4          1        16109
# 3           2          1        12763
# 4           3          2        18699
# ..        ...        ...          ...
# 95          1          2        15598
# 96          1          2        14240
# 97          4          3        16336
# 98          1          1        14623
# 99          1          3        13500
#
# [100 rows x 3 columns]

# %%
#Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter


dataFrame.columns = ['bedrs','bathrs','price_sqr_meter']
dataFrame
# Out:
#     bedrs  bathrs  price_sqr_meter
# 0       1       1            24247
# 1       4       2            24274
# 2       4       1            16109
# 3       2       1            12763
# 4       3       2            18699
# ..    ...     ...              ...
# 95      1       2            15598
# 96      1       2            14240
# 97      4       3            16336
# 98      1       1            14623
# 99      1       3            13500
#
# [100 rows x 3 columns]

# %%
#Step 5. Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'



bigcolumn = dataFrame['bedrs'].append(dataFrame['bathrs'].append(dataFrame['price_sqr_meter']))
bigcolumn
# Out:
# 0         1
# 1         4
# 2         4
# 3         2
# 4         3
#       ...
# 95    15598
# 96    14240
# 97    16336
# 98    14623
# 99    13500
# Length: 300, dtype: int32

# %%
#Step 6. Ops it seems it is going only until index 99. Is it true?
# Yes, from the above output it can be seen that the index is going upto 99.


#Step 7. Reindex the DataFrame so it goes from 0 to 299
bigcolumn.reset_index(drop=True)
# Out:
# 0          1
# 1          4
# 2          4
# 3          2
# 4          3
#        ...
# 295    15598
# 296    14240
# 297    16336
# 298    14623
# 299    13500
# Length: 300, dtype: int32

# %% [markdown]
# # Question 4: Python

# %% [markdown]
# Wind Statistics
# The data have been modified to contain some missing values, identified by NaN.
# Using pandas should make this exercise easier, in particular for the bonus question.
#
# You should be able to perform all of these operations without using a for loop or
# other looping construct.
# The data in 'wind.data' has the following format:
# Yr Mo Dy RPT VAL ROS KIL SHA BIR DUB CLA MUL CLO BEL
# MAL
# 61 1 1 15.04 14.96 13.17 9.29 NaN 9.87 13.67 10.25 10.83 12.58 18.50 15.04
# 61 1 2 14.71 NaN 10.83 6.50 12.62 7.67 11.50 10.04 9.79 9.67 17.54 13.83
# 61 1 3 18.50 16.88 12.33 10.13 11.17 6.17 11.25 NaN 8.50 7.67 12.75 12.71
# The first three columns are year, month, and day. The remaining 12 columns are
# average windspeeds in knots at 12 locations in Ireland on that day.

# %%
#Step 1. Import the necessary libraries

import pandas as pd
import numpy as np

# %%
#Step 2. Import the dataset from this address
#Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index.
#Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.

data = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data", delim_whitespace=True)
data.head()


data["Date"]= pd.to_datetime(data[['Yr', 'Mo', 'Dy']].rename(columns={'Yr': 'year','Mo': 'month','Dy': 'day'}).assign(year=lambda x: x['year']+1900))
data.drop(['Yr', 'Mo', 'Dy'], axis=1, inplace=True)
data
# Out:
#         RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL    CLO  \
# 0     15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83  12.58
# 1     14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04   9.79   9.67
# 2     18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN   8.50   7.67
# 3     10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79   5.83   5.88
# 4     13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54  10.92  10.34
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59  14.04  14.00
# 6570  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25  15.25  18.05
# 6571  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46  14.50  16.42
# 6572  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87  12.46  12.12
# 6573  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63  11.58  11.38
#
#         BEL    MAL       Date
# 0     18.50  15.04 1961-01-01
# ...

# %%
#Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].


data = data.set_index('Date')
data
# Out:
#               RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# Date
# 1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83
# 1961-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04   9.79
# 1961-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN   8.50
# 1961-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54  10.92
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59  14.04
# 1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25  15.25
# 1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46  14.50
# 1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87  12.46
# 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63  11.58
#
#               CLO    BEL    MAL
# Date
# 1961-01-01  12.58  18.50  15.04
# ...

# %%
#Step 6. Compute how many values are missing for each location over the entire record.They should be ignored in all calculations below.

data.isnull().sum()
# Out:
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %%
#Step 7. Compute how many non-missing values there are in total


data = data.dropna()
data.isnull().sum()
data.count()
# Out:
# RPT    6546
# VAL    6546
# ROS    6546
# KIL    6546
# SHA    6546
# BIR    6546
# DUB    6546
# CLA    6546
# MUL    6546
# CLO    6546
# BEL    6546
# MAL    6546
# dtype: int64

# %%
#Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.A single number for the entire dataset.

data.mean(axis=1).mean(axis=0)
# Out:
# 10.222465245951703

# %%
#Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds
#at each location over all the days.A different set of numbers for each location.


loc_stats = pd.DataFrame()
loc_stats["minium"] = data.min(axis=0)
loc_stats["maximum"] = data.max(axis=0)
loc_stats["mean"] = data.mean(axis=0)
loc_stats["standard deviation"] = data.std(axis=0)
loc_stats
# Out:
#      minium  maximum       mean  standard deviation
# RPT    0.67    35.80  12.359979            5.618805
# VAL    0.21    33.37  10.640267            5.268695
# ROS    1.50    33.84  11.656396            5.007805
# KIL    0.00    28.46   6.298587            3.600942
# SHA    0.13    37.54  10.448923            4.933988
# BIR    0.00    26.16   7.085066            3.967735
# DUB    0.00    30.37   9.793006            4.978030
# CLA    0.00    31.08   8.486601            4.498299
# MUL    0.00    25.88   8.490257            4.165947
# CLO    0.04    28.21   8.696705            4.500488
# BEL    0.13    42.38  13.110668            5.829054
# MAL    0.67    42.54  15.603129            6.702178

# %%
#Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds 
#across all the locations at each day. A different set of numbers for each day.

day_stats = pd.DataFrame()
day_stats["minium"] = data.min(axis=1)
day_stats["maxium"] = data.max(axis=1)
day_stats["mean"] = data.mean(axis=1)
day_stats["standard deviation"] = data.std(axis=1)
day_stats
# Out:
#             minium  maxium       mean  standard deviation
# Date
# 1961-01-04    1.79   11.75   6.619167            3.198126
# 1961-01-05    6.17   13.33  10.630000            2.445356
# 1961-01-06    4.42   13.21   8.240000            2.998063
# 1961-01-07    4.96   14.29  10.385000            3.072114
# 1961-01-08    5.91   16.62  10.487500            3.547237
# ...            ...     ...        ...                 ...
# 1978-12-27    8.08   40.08  16.708333            7.868076
# 1978-12-28    5.00   41.46  15.150000            9.687857
# 1978-12-29    8.71   29.58  14.890000            5.756836
# 1978-12-30    9.13   28.79  15.367500            5.540437
# 1978-12-31    9.59   27.29  15.402500            5.702483
#
# [6546 rows x 4 columns]

# %%
#Step 11. Find the average windspeed in January for each location. Treat January 1961 and January 1962 both as January.

data = data.reset_index() 
meanJan = data[data['Date'].dt.month == 1]
meanJan = meanJan.mean(axis = 0)
meanJan
# Out:
# RPT    14.831609
# VAL    12.885389
# ROS    13.276275
# KIL     7.152477
# SHA    11.644467
# BIR     8.030561
# DUB    11.788336
# CLA     9.486962
# MUL     9.511501
# CLO    10.024069
# BEL    14.527848
# MAL    18.041826
# dtype: float64

# %%
#Step 12. Downsample the record to a yearly frequency for each location.

data.groupby(data['Date'].dt.year).sum()
# Out:
#           RPT      VAL      ROS      KIL      SHA      BIR      DUB      CLA  \
# Date
# 1961  4150.58  3470.45  3836.17  2327.79  3652.53  2589.83  3275.31  2952.87
# 1962  4443.47  3674.61  4240.60  2521.09  3870.60  2684.35  3997.61  3196.39
# 1963  4676.91  3955.50  4577.52  2675.47  4279.30  3078.67  4042.63  3772.84
# 1964  4525.10  3996.78  4430.20  2484.33  4192.34  2770.94  3754.85  3465.05
# 1965  4544.75  4042.57  4324.80  2503.34  4024.05  2729.51  3875.83  3241.17
# 1966  4913.62  4218.38  4387.53  2681.19  4308.84  2844.69  3861.63  3224.81
# 1967  4649.06  4011.71  4284.88  2607.35  4245.22  2689.38  3887.99  3403.85
# 1968  4331.84  3831.36  4175.97  2370.83  3938.44  2220.64  3242.46  3021.52
# 1969  4075.72  3549.15  3979.23  2105.31  3603.98  2259.34  3126.04  2814.66
# 1970  4599.12  3915.33  4281.54  2269.27  3857.09  2777.45  3507.61  3042.14
# 1971  4114.69  3319.74  4047.24  1913.15  3445.72  2225.46  3060.85  2466.42
# ...

# %%
#Step 13. Downsample the record to a monthly frequency for each location.

monthData = data
monthData.groupby([monthData['Date'].dt.year.rename('year'),monthData['Date'].dt.month.rename('month')]).sum()
# Out:
#                RPT     VAL     ROS     KIL     SHA     BIR     DUB     CLA  \
# year month
# 1961 1      377.16  291.86  336.97  177.84  273.24  212.53  270.48  225.44
#      2      426.45  390.97  376.22  240.31  358.23  283.00  308.57  305.40
#      3      287.82  299.63  281.34  191.72  277.17  231.66  245.93  251.89
#      4      321.68  282.83  299.94  174.92  253.05  194.85  207.76  212.84
#      5      280.69  237.88  295.10  167.79  265.45  185.75  214.08  229.79
# ...            ...     ...     ...     ...     ...     ...     ...     ...
# 1978 8      299.00  256.04  280.00  139.59  228.41  183.99  175.16  167.95
#      9      327.41  326.85  319.05  171.75  311.16  278.35  323.71  287.49
#      10     306.83  268.80  288.17  146.36  264.28  210.00  251.58  227.47
#      11     484.55  444.08  405.24  219.52  344.25  262.29  344.77  289.72
#      12     501.44  426.19  484.69  219.94  353.36  286.49  374.40  316.04
#
#                MUL     CLO     BEL     MAL
# year month
# ...

# %%
#Step 14. Downsample the record to a weekly frequency for each location.

dataforWeek = data
dataforWeek.groupby([dataforWeek['Date'].dt.year.rename('year'),dataforWeek['Date'].dt.month.rename('month'), dataforWeek['Date'].dt.week.rename('week')]).sum()
# Out:
#                     RPT     VAL     ROS    KIL     SHA    BIR     DUB    CLA  \
# year month week
# 1961 1     1      61.58   52.04   50.25  28.29   42.53  31.21   54.68  29.66
#            2      87.28   62.77   83.71  32.41   51.46  35.51   52.75  47.74
#            3      72.60   57.00   70.09  25.76   53.80  41.63   46.97  43.75
#            4     119.28   89.08  105.29  71.50   97.95  84.10   86.70  85.87
#            5      36.42   30.97   27.63  19.88   27.50  20.08   29.38  18.42
# ...                 ...     ...     ...    ...     ...    ...     ...    ...
# 1978 12    48     56.20   50.34   56.08  29.50   44.17  41.79   51.33  38.84
#            49    145.18  134.33  119.24  68.44  107.01  89.42  101.06  87.42
#            50    117.31  102.85  104.91  48.42   79.78  50.91   71.46  55.77
#            51     78.09   56.06   92.21  28.03   54.78  44.03   54.59  60.67
#            52    104.66   82.61  112.25  45.55   67.62  60.34   95.96  73.34
#
# ...

# %%
#Step 15. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume 
#that the first week starts on January 2 1961) for the first 52 weeks.


newData = dataforWeek.groupby([dataforWeek['Date'].dt.year.rename('Year'),dataforWeek['Date'].dt.week.rename('Week')]).sum()
newDatamean = pd.Series(newData.head(52).mean(axis=1))
newDataminimum = pd.Series(newData.head(52).min(axis=1))
newDatamaximum = pd.Series(newData.head(52).max(axis=1))
newDatastd = pd.Series(newData.head(52).std(axis=1))
weekCalc = pd.DataFrame({'Min':newDataminimum, 'Max':newDatamaximum, 'Mean':newDatamean, 'Std Deviation':newDatastd})
weekCalc
# Out:
#              Min     Max        Mean  Std Deviation
# Year Week
# 1961 1     28.29   66.13   46.361667      12.623655
#      2     32.41   87.28   58.472500      19.037546
#      3     25.76   72.60   50.762500      14.248717
#      4     71.50  134.33   96.860833      18.810359
#      5     57.73  117.79   82.602500      19.651171
#      6     75.42  152.83  111.240833      22.031887
#      7     57.18  118.54   81.348333      16.366597
#      8     59.67  114.13   88.230000      16.550263
#      9     39.50   85.87   56.875000      12.829530
#      10    31.05   96.41   58.920000      16.832939
#      11    49.59  135.45   82.294167      23.242226
#      12    46.54  126.94   73.240000      21.503822
#      13    33.67   64.55   47.035000       9.287854
#      14    41.71   95.25   65.886667      16.798883
#      15    34.63   66.38   47.919167      12.626817
#      16    54.38   95.34   71.026667      13.271604
#      17    33.61   70.82   52.115000      13.048908
# ...

# %% [markdown]
# # Question 5 Python

# %%
#Step 1. Import the necessary libraries

import numpy as np
import pandas as pd

# %%
#Step 2. Import the dataset from this address
#Step 3. Assign it to a variable called chipo.

chipo = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv", delimiter="\t")

# %%
#Step 4. See the first 10 entries

chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
#Step 5. What is the number of observations in the dataset?

chipo.shape[0]
# Out:
# 4622

# %%
#Step 6. What is the number of columns in the dataset?

chipo.shape[1]
# Out:
# 5

# %%
#Step 7. Print the name of all the columns.

chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
#Step 8. How is the dataset indexed?

chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
#Step 9. Which was the most-ordered item?

mostOrdered=chipo["item_name"].value_counts().reset_index().loc[0, "index"]
print("Most ordered item is:", mostOrdered)
# Out:
# Most ordered item is: Chicken Bowl

# %%
#Step 10. For the most-ordered item, how many items were ordered?

itemsOfmostordered=chipo["item_name"].value_counts().reset_index().loc[0, "item_name"]
print("Number of items ordered on most ordered item is: ", itemsOfmostordered)
# Out:
# Number of items ordered on most ordered item is:  726

# %%
#Step 11. What was the most ordered item in the choice_description column?

mostChoice = chipo["choice_description"].value_counts().reset_index().loc[0, "index"]
print("Most ordered item in choice_description:", mostChoice)
# Out:
# Most ordered item in choice_description: [Diet Coke]

# %%
#Step 12. How many items were orderd in total?

chipo['quantity'].sum()
# Out:
# 4972

# %%
#Step 13.
#• Turn the item price into a float
#• Check the item price type
#• Create a lambda function and change the type of item price
#• Check the item price type


chipo["item_price"] = chipo["item_price"].apply(lambda x: float(x[1:]))

# %%
chipo["item_price"].dtypes
# Out:
# dtype('float64')

# %%
#Step 14. How much was the revenue for the period in the dataset?

chipo['revenue_per_order'] = chipo['quantity'] * chipo['item_price']
revenue = chipo['revenue_per_order'].sum()
print("total revenue over the period is: ", revenue)
# Out:
# total revenue over the period is:  39237.02

# %%
#Step 15. How many orders were made in the period?

totalOrder = chipo['order_id'].nunique()
print("Number of order over the period is: ", totalOrder)
# Out:
# Number of order over the period is:  1834

# %%
#Step 16. What is the average revenue amount per order?

chipo.groupby("order_id")["revenue_per_order"].mean()
# Out:
# order_id
# 1        2.890000
# 2       33.960000
# 3        6.335000
# 4       10.500000
# 5        6.850000
#           ...
# 1830    11.500000
# 1831     4.300000
# 1832     6.600000
# 1833    11.750000
# 1834     9.583333
# Name: revenue_per_order, Length: 1834, dtype: float64

# %%
#Step 17. How many different items are sold?

print("Total unique items: ", len(chipo["item_name"].unique()))
# Out:
# Total unique items:  50

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Question 6

# %% [markdown]
# Create a line plot showing the number of marriages and divorces per capita in the
# U.S. between 1867 and 2014. Label both lines and show the legend.
# Don't forget to label your axes!

# %%
marriageDivorce = pd.read_csv('us-marriages-divorces-1867-2014.csv')


marriageDivorce.plot.line(x="Year", y=["Marriages_per_1000", "Divorces_per_1000"])

plt.title('No. of Marriages & Divorces')
plt.xlabel("Year")
plt.ylabel("No. of Marriages & Divorces")
plt.show()

# %% [markdown]
# # Question 7

# %% [markdown]
# Create a vertical bar chart comparing the number of marriages and divorces per
# capita in the U.S. between 1900, 1950, and 2000.
# Don't forget to label your axes!

# %%
threeData = marriageDivorce[(marriageDivorce.Year == 1900) | (marriageDivorce.Year == 1950) | (marriageDivorce.Year == 2000)]
threeData = threeData.drop(columns = ['Marriages', 'Divorces','Population'])
threeData = threeData.set_index('Year')
threeData.plot.bar()

plt.title('US Marriages & Divorces per captia between 1900, 1950 & 2000')
plt.xlabel('Year')
plt.ylabel('No. of Marriages & Divorces')
# Out:
# Text(0, 0.5, 'No. of Marriages & Divorces')

# %% [markdown]
# # Question 8

# %% [markdown]
# Create a horizontal bar chart that compares the deadliest actors in Hollywood. Sort
# the actors by their kill count and label each bar with the corresponding actor's name.
# Don't forget to label your axes!

# %%
import pandas as pd
import matplotlib.pyplot as plt

actorData = pd.read_csv('actor_kill_counts.csv')
actorData = actorData.sort_values(by="Count")


plt.barh(actorData['Actor'], actorData['Count'],  color='#A4CCD9', label='Kill')

plt.title('Actors by their kill count')
plt.xlabel('No. of Kills')
plt.ylabel('Name of Actors')

plt.show()

# %% [markdown]
# # Question 9

# %% [markdown]
# Create a pie chart showing the fraction of all Roman Emperors that were
# assassinated.
# Make sure that the pie chart is an even circle, labels the categories, and shows the
# percentage breakdown of the categories.

# %%
import pandas as pd
import matplotlib.pyplot as plt

romanEmperorreigns = pd.read_csv('roman-emperor-reigns.csv')
deathCause = romanEmperorreigns.groupby('Cause_of_Death').count()[['Emperor']]

emperor = pd.Series(deathCause['Emperor'])
cause_death = pd.Series(deathCause.index)

fig9, ax9 = plt.subplots()

ax9.pie(emperor, labels=cause_death,autopct='%1.1f%%')
ax9.axis('equal')

plt.title('Roman Emperor Assassination')
plt.show()

# %% [markdown]
# # Question 10

# %% [markdown]
# Create a scatter plot showing the relationship between the total revenue earned by
# arcades and the number of Computer Science PhDs awarded in the U.S. between
# 2000 and 2009.
# Don't forget to label your axes!
# Color each dot according to its year.

# %%
import pandas as pd
import matplotlib.pyplot as plt


arcadeCSdata= pd.read_csv('arcade-revenue-vs-cs-doctorates.csv')
colors = {2000:'#C4E57D',2001:'#2AC280', 2002:'#FFAE39',2003:'#DC5B3B',2004:'#52E397', 
          2005:'#C5CBA3',2006:'#9CD5F6',2007:'#6E50D9', 2008:'#9A5E59',2009:'#9BC8F5'}
fig10, ax10 = plt.subplots()
for i in range (len(arcadeCSdata['Total Arcade Revenue (billions)'])):
    ax10.scatter(arcadeCSdata['Total Arcade Revenue (billions)'][i],arcadeCSdata['Computer Science Doctorates Awarded (US)'][i], color = colors[arcadeCSdata['Year'][i]])
ax10.set_title('Relationship between Arcade Revenue and CS Doctorates between 2000 and 2009')
ax10.set_xlabel('Total Arcade Revenue (billions)')
ax10.set_ylabel('Computer Science Doctorates Awarded (US)')
# Out:
# Text(0, 0.5, 'Computer Science Doctorates Awarded (US)')
